# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
import pathlib

# %%
# widths are the spaces for each columns in the DAT file.
widths = [
    7, #loc
    6, #type
    5, #no
    10, #status
    3, #ind
    5, #stock_type
    24, #stock_ident_no
    5, #sheet
    5, #quantity
    6, #r
]

# %%
columns_names = [
    "loc",
    "type",
    "no",
    "status",
    "ind",
    "stock_type",
    "stock_ident_no",
    "sheet",
    "quantity",
    "r",
]

# %%
file = pathlib.Path("BESTAND.DAT")
if file.exists():
    print ("File: BESTAND.DAT found")
    print ("Generating speadsheet...")
    # run the function.
else:
    print ("File: BESTAND.DAT was not found. Please provide the file before running the macro.")
# Out:
# File: BESTAND.DAT found

# %%
bestand = pd.read_fwf("BESTAND.DAT", widths=widths, colspecs='infer')

# %%
bestand = bestand.iloc[9:]
bestand.columns = columns_names
bestand['quantity'] = bestand['quantity'].astype(float)

# %%
bestand = (
    bestand
        [["stock_ident_no","quantity"]]
        .groupby(['stock_ident_no'])['quantity'].agg(sum)
        .to_frame(name=None) # change series in dataframe.
)

# %%
data = {
    "steel_com_16g_5x10":{"safety":15, "dimensions":"5' X 10'", "no_item": "11100409", "description1": "STEEL 0.060\"", "description2":"[16G]"},
    "steel_com_14g_5x10":{"safety":10, "dimensions":"5' X 10'", "no_item": "11100356", "description1": "STEEL 0.075\"", "description2":"[14G]"},
    "steel_com_11g_5x10":{"safety":54, "dimensions":"5' X 10'", "no_item": "11100638", "description1": "STEEL 0.120\"", "description2":"[11G]"},
    "steel_com_10g_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "11100578", "description1": "STEEL 10g\"", "description2":"[10G]"},
    "steel_44w_0.187_5x10":{"safety":34, "dimensions":"5' X 10'", "no_item": "11100567", "description1": "STEEL 0.187\"", "description2":"[3/16G]"},
    "steel_44w_0.250_5x10":{"safety":39, "dimensions":"5' X 10'", "no_item": "11100400", "description1": "STEEL 0.250\"", "description2":"[1/4]"},
    "steel_44w_0.312_5x10":{"safety":4, "dimensions":"5' X 10'", "no_item": "11100379", "description1": "STEEL 0.312\"", "description2":"[5/16]"},
    "steel_44w_0.375_5x10":{"safety":8, "dimensions":"5' X 10'", "no_item": "11100282", "description1": "STEEL 0.375\"", "description2":"[3/8]"},
    "steel_44w_0.500_5x10":{"safety":6, "dimensions":"5' X 10'", "no_item": "11100285", "description1": "STEEL 0.500\"", "description2":"[1/2]"},
    "steel_44w_0.625_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "11100075", "description1": "STEEL 0.625\"", "description2":"[5/8]"},
    "steel_44w_0.750_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "11100269", "description1": "STEEL 0.750\"", "description2":"[3/4]"},
    "steel_44w_1.000_4x10":{"safety":2, "dimensions":"4' X 8'", "no_item": "11100284", "description1": "STEEL 1.000\"", "description2":"[1PO]"},
    "steel_44w_1.000_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "11100284", "description1": "STEEL 1.000\"", "description2":"[1PO]"},
    "steel_flr_0.187_5x10":{"safety":8, "dimensions":"5' X 10'", "no_item": "11100580", "description1": "ANTI-DERAPANT 0.187\"", "description2":"[3/16]"},
    "steel_galv_11g_4x10":{"safety":3, "dimensions":"4' X 10'", "no_item": "11100525", "description1": "STEEL GALV 0.120\"", "description2":"[11G]"},
    "ss_304_16g_5x10":{"safety":5, "dimensions":"5' X 10'", "no_item": "11600005", "description1": "SS 304 0.062\"", "description2":"[16G]"},
    "ss_304_14g_5x10":{"safety":5, "dimensions":"5' X 10'", "no_item": "11600067", "description1": "SS 304 0.078\"", "description2":"[14G]"},
    "ss_304_11g_5x10":{"safety":15, "dimensions":"5' X 10'", "no_item": "11600001", "description1": "SS 304 0.125\"", "description2":"[11G]"},
    "ss_304_0.250_5x10":{"safety":5, "dimensions":"5' X 10'", "no_item": "11600028", "description1": "SS 304 0.250\"", "description2":"[1/4]"},
    "ss_304_0.375_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "11600029", "description1": "SS 304 0.375\"", "description2":"[3/8]"},
    "ss_304_0.500_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "11600039", "description1": "SS 304 0.500\"", "description2":"[1/2]"},
    "ss 304 2b 0.187 5x10":{"safety":5, "dimensions":"5' X 10'", "no_item": "11600021", "description1": "SS 304 2B 0.187\"", "description2":"[3/16]"},
    "ss_304_16g_no4_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "171237", "description1": "SS 304 NO4 0.062\"", "description2":"[16G]"},
    "ss_304_11g_no4_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "171236", "description1": "SS 304 NO4 0.125\"", "description2":"[11G]"},
    "ss_304_0.187_no4_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "212826", "description1": "SS 304 NO4 0.187\"", "description2":"[3/16]"},
    "ss_304_0.250_no4_5x10":{"safety":2, "dimensions":"5' X 10'", "no_item": "212287", "description1": "SS 304 NO4 0.250\"", "description2":"[1/4]"},
}

# %%
# change the dict to a dataframe.
cmf = pd.DataFrame.from_dict(data , orient='index', columns=['no_item','description1','description2','dimensions','safety'])
# assign type to columns
cmf = cmf.astype({"no_item": str,"description1": str,"description2":str, "dimensions":str, "safety":int})
# change indexes to lower case cmf and bestand.
cmf.index = cmf.index.str.lower()
bestand.index = bestand.index.str.lower()

# %%
cmf
# Out:
#                         no_item          description1 description2 dimensions  \
# steel_com_16g_5x10     11100409          STEEL 0.060"        [16G]   5' X 10'
# steel_com_14g_5x10     11100356          STEEL 0.075"        [14G]   5' X 10'
# steel_com_11g_5x10     11100638          STEEL 0.120"        [11G]   5' X 10'
# steel_com_10g_5x10     11100578            STEEL 10g"        [10G]   5' X 10'
# steel_44w_0.187_5x10   11100567          STEEL 0.187"      [3/16G]   5' X 10'
# steel_44w_0.250_5x10   11100400          STEEL 0.250"        [1/4]   5' X 10'
# steel_44w_0.312_5x10   11100379          STEEL 0.312"       [5/16]   5' X 10'
# steel_44w_0.375_5x10   11100282          STEEL 0.375"        [3/8]   5' X 10'
# steel_44w_0.500_5x10   11100285          STEEL 0.500"        [1/2]   5' X 10'
# steel_44w_0.625_5x10   11100075          STEEL 0.625"        [5/8]   5' X 10'
# steel_44w_0.750_5x10   11100269          STEEL 0.750"        [3/4]   5' X 10'
# steel_44w_1.000_4x10   11100284          STEEL 1.000"        [1PO]    4' X 8'
# steel_44w_1.000_5x10   11100284          STEEL 1.000"        [1PO]   5' X 10'
# steel_flr_0.187_5x10   11100580  ANTI-DERAPANT 0.187"       [3/16]   5' X 10'
# steel_galv_11g_4x10    11100525     STEEL GALV 0.120"        [11G]   4' X 10'
# ss_304_16g_5x10        11600005         SS 304 0.062"        [16G]   5' X 10'
# ss_304_14g_5x10        11600067         SS 304 0.078"        [14G]   5' X 10'
# ss_304_11g_5x10        11600001         SS 304 0.125"        [11G]   5' X 10'
# ss_304_0.250_5x10      11600028         SS 304 0.250"        [1/4]   5' X 10'
# ss_304_0.375_5x10      11600029         SS 304 0.375"        [3/8]   5' X 10'
# ss_304_0.500_5x10      11600039         SS 304 0.500"        [1/2]   5' X 10'
# ss 304 2b 0.187 5x10   11600021      SS 304 2B 0.187"       [3/16]   5' X 10'
# ss_304_16g_no4_5x10      171237     SS 304 NO4 0.062"        [16G]   5' X 10'
# ss_304_11g_no4_5x10      171236     SS 304 NO4 0.125"        [11G]   5' X 10'
# ss_304_0.187_no4_5x10    212826     SS 304 NO4 0.187"       [3/16]   5' X 10'
# ss_304_0.250_no4_5x10    212287     SS 304 NO4 0.250"        [1/4]   5' X 10'
#
#                        safety
# steel_com_16g_5x10         15
# steel_com_14g_5x10         10
# steel_com_11g_5x10         54
# steel_com_10g_5x10          2
# steel_44w_0.187_5x10       34
# steel_44w_0.250_5x10       39
# steel_44w_0.312_5x10        4
# steel_44w_0.375_5x10        8
# steel_44w_0.500_5x10        6
# steel_44w_0.625_5x10        2
# steel_44w_0.750_5x10        2
# steel_44w_1.000_4x10        2
# steel_44w_1.000_5x10        2
# steel_flr_0.187_5x10        8
# steel_galv_11g_4x10         3
# ss_304_16g_5x10             5
# ss_304_14g_5x10             5
# ss_304_11g_5x10            15
# ss_304_0.250_5x10           5
# ss_304_0.375_5x10           2
# ss_304_0.500_5x10           2
# ss 304 2b 0.187 5x10        5
# ss_304_16g_no4_5x10         2
# ss_304_11g_no4_5x10         2
# ss_304_0.187_no4_5x10       2
# ss_304_0.250_no4_5x10       2

# %%
bestand
# Out:
#                        quantity
# stock_ident_no
# ss 304 2b 0.187 5x10        4.0
# ss_304_0.187_no4_5x10      10.0
# ss_304_0.250_5x10           5.0
# ss_304_0.250_no4_5x10       7.0
# ss_304_0.375_5x10           1.0
# ss_304_0.500_5x10           2.0
# ss_304_11g_5x10            16.0
# ss_304_11g _no4_5x10        4.0
# ss_304_14g_5x10             4.0
# ss_304_16g_5x10             9.0
# ss_304_16g_no4_5x10         3.0
# ss_316_16g_4x8              1.0
# steel_44w_0.187_5x10       33.0
# steel_44w_0.250_5x10       22.0
# steel_44w_0.312_5x10        1.0
# steel_44w_0.375_5x10        1.0
# steel_44w_0.500_5x10        5.0
# steel_44w_0.625_5x10        2.0
# steel_44w_0.750_5x10        1.0
# steel_44w_1.000_4x8         3.0
# steel_44w_1.000_5x10        3.0
# steel_com_10g_5x10          6.0
# steel_com_11g_5x10         43.0
# steel_com_14g_5x10         13.0
# steel_com_16g_4x8          12.0
# steel_com_16g_5x10         13.0
# steel_flr_0.187_5x10        8.0
# steel_galv_11g_4x10         4.0

# %%
bestand = bestand.join(cmf)
bestand
# Out:
#                        quantity   no_item          description1 description2  \
# stock_ident_no
# ss 304 2b 0.187 5x10        4.0  11600021      SS 304 2B 0.187"       [3/16]
# ss_304_0.187_no4_5x10      10.0    212826     SS 304 NO4 0.187"       [3/16]
# ss_304_0.250_5x10           5.0  11600028         SS 304 0.250"        [1/4]
# ss_304_0.250_no4_5x10       7.0    212287     SS 304 NO4 0.250"        [1/4]
# ss_304_0.375_5x10           1.0  11600029         SS 304 0.375"        [3/8]
# ss_304_0.500_5x10           2.0  11600039         SS 304 0.500"        [1/2]
# ss_304_11g_5x10            16.0  11600001         SS 304 0.125"        [11G]
# ss_304_11g _no4_5x10        4.0       NaN                   NaN          NaN
# ss_304_14g_5x10             4.0  11600067         SS 304 0.078"        [14G]
# ss_304_16g_5x10             9.0  11600005         SS 304 0.062"        [16G]
# ss_304_16g_no4_5x10         3.0    171237     SS 304 NO4 0.062"        [16G]
# ss_316_16g_4x8              1.0       NaN                   NaN          NaN
# steel_44w_0.187_5x10       33.0  11100567          STEEL 0.187"      [3/16G]
# steel_44w_0.250_5x10       22.0  11100400          STEEL 0.250"        [1/4]
# steel_44w_0.312_5x10        1.0  11100379          STEEL 0.312"       [5/16]
# steel_44w_0.375_5x10        1.0  11100282          STEEL 0.375"        [3/8]
# steel_44w_0.500_5x10        5.0  11100285          STEEL 0.500"        [1/2]
# steel_44w_0.625_5x10        2.0  11100075          STEEL 0.625"        [5/8]
# steel_44w_0.750_5x10        1.0  11100269          STEEL 0.750"        [3/4]
# steel_44w_1.000_4x8         3.0       NaN                   NaN          NaN
# steel_44w_1.000_5x10        3.0  11100284          STEEL 1.000"        [1PO]
# steel_com_10g_5x10          6.0  11100578            STEEL 10g"        [10G]
# steel_com_11g_5x10         43.0  11100638          STEEL 0.120"        [11G]
# steel_com_14g_5x10         13.0  11100356          STEEL 0.075"        [14G]
# steel_com_16g_4x8          12.0       NaN                   NaN          NaN
# steel_com_16g_5x10         13.0  11100409          STEEL 0.060"        [16G]
# steel_flr_0.187_5x10        8.0  11100580  ANTI-DERAPANT 0.187"       [3/16]
# steel_galv_11g_4x10         4.0  11100525     STEEL GALV 0.120"        [11G]
#
#                       dimensions  safety
# stock_ident_no
# ss 304 2b 0.187 5x10    5' X 10'     5.0
# ss_304_0.187_no4_5x10   5' X 10'     2.0
# ss_304_0.250_5x10       5' X 10'     5.0
# ss_304_0.250_no4_5x10   5' X 10'     2.0
# ss_304_0.375_5x10       5' X 10'     2.0
# ss_304_0.500_5x10       5' X 10'     2.0
# ss_304_11g_5x10         5' X 10'    15.0
# ss_304_11g _no4_5x10         NaN     NaN
# ss_304_14g_5x10         5' X 10'     5.0
# ss_304_16g_5x10         5' X 10'     5.0
# ss_304_16g_no4_5x10     5' X 10'     2.0
# ss_316_16g_4x8               NaN     NaN
# steel_44w_0.187_5x10    5' X 10'    34.0
# steel_44w_0.250_5x10    5' X 10'    39.0
# steel_44w_0.312_5x10    5' X 10'     4.0
# steel_44w_0.375_5x10    5' X 10'     8.0
# steel_44w_0.500_5x10    5' X 10'     6.0
# steel_44w_0.625_5x10    5' X 10'     2.0
# steel_44w_0.750_5x10    5' X 10'     2.0
# steel_44w_1.000_4x8          NaN     NaN
# steel_44w_1.000_5x10    5' X 10'     2.0
# steel_com_10g_5x10      5' X 10'     2.0
# steel_com_11g_5x10      5' X 10'    54.0
# steel_com_14g_5x10      5' X 10'    10.0
# steel_com_16g_4x8            NaN     NaN
# steel_com_16g_5x10      5' X 10'    15.0
# steel_flr_0.187_5x10    5' X 10'     8.0
# steel_galv_11g_4x10     4' X 10'     3.0

# %%
# substract difference.
bestand["order"] = bestand["safety"] - bestand["quantity"]
# calculate surfaces.
bestand["quantitypi2"] = bestand["order"] * 50
# fill na values to zero.
bestand[["safety","order","quantitypi2"]] = bestand[["safety","order","quantitypi2"]].fillna(0)
# Rename headers
bestand.columns = [
    "Quantity",
    "Item number",
    "Description 1",
    "Description 2",
    "Dimensions",
    "Safety stock",
    "To order",
    "Surface (ft^2)",
]
# convert number to int.
bestand = bestand.astype({"Quantity": int,"Safety stock": int,"To order":int, "Surface (ft^2)":int})
# order headers.
bestand =bestand[[ 'Item number', 'Description 1', 'Description 2','Dimensions', 'Safety stock', 'Quantity','To order', 'Surface (ft^2)']]

# %%
# change negative values to zero.
surfaces = bestand[["Surface (ft^2)"]].clip(lower=0)
bestand["Surface (ft^2)"] = surfaces
orders = bestand[["To order"]].clip(lower=0)
bestand["To order"] = orders

# %%
bestand
# Out:
#                       Item number         Description 1 Description 2  \
# stock_ident_no
# ss 304 2b 0.187 5x10     11600021      SS 304 2B 0.187"        [3/16]
# ss_304_0.187_no4_5x10      212826     SS 304 NO4 0.187"        [3/16]
# ss_304_0.250_5x10        11600028         SS 304 0.250"         [1/4]
# ss_304_0.250_no4_5x10      212287     SS 304 NO4 0.250"         [1/4]
# ss_304_0.375_5x10        11600029         SS 304 0.375"         [3/8]
# ss_304_0.500_5x10        11600039         SS 304 0.500"         [1/2]
# ss_304_11g_5x10          11600001         SS 304 0.125"         [11G]
# ss_304_11g _no4_5x10          NaN                   NaN           NaN
# ss_304_14g_5x10          11600067         SS 304 0.078"         [14G]
# ss_304_16g_5x10          11600005         SS 304 0.062"         [16G]
# ss_304_16g_no4_5x10        171237     SS 304 NO4 0.062"         [16G]
# ss_316_16g_4x8                NaN                   NaN           NaN
# steel_44w_0.187_5x10     11100567          STEEL 0.187"       [3/16G]
# steel_44w_0.250_5x10     11100400          STEEL 0.250"         [1/4]
# steel_44w_0.312_5x10     11100379          STEEL 0.312"        [5/16]
# steel_44w_0.375_5x10     11100282          STEEL 0.375"         [3/8]
# steel_44w_0.500_5x10     11100285          STEEL 0.500"         [1/2]
# steel_44w_0.625_5x10     11100075          STEEL 0.625"         [5/8]
# steel_44w_0.750_5x10     11100269          STEEL 0.750"         [3/4]
# steel_44w_1.000_4x8           NaN                   NaN           NaN
# steel_44w_1.000_5x10     11100284          STEEL 1.000"         [1PO]
# steel_com_10g_5x10       11100578            STEEL 10g"         [10G]
# steel_com_11g_5x10       11100638          STEEL 0.120"         [11G]
# steel_com_14g_5x10       11100356          STEEL 0.075"         [14G]
# steel_com_16g_4x8             NaN                   NaN           NaN
# steel_com_16g_5x10       11100409          STEEL 0.060"         [16G]
# steel_flr_0.187_5x10     11100580  ANTI-DERAPANT 0.187"        [3/16]
# steel_galv_11g_4x10      11100525     STEEL GALV 0.120"         [11G]
#
#                       Dimensions  Safety stock  Quantity  To order  \
# stock_ident_no
# ss 304 2b 0.187 5x10    5' X 10'             5         4         1
# ss_304_0.187_no4_5x10   5' X 10'             2        10         0
# ss_304_0.250_5x10       5' X 10'             5         5         0
# ss_304_0.250_no4_5x10   5' X 10'             2         7         0
# ss_304_0.375_5x10       5' X 10'             2         1         1
# ss_304_0.500_5x10       5' X 10'             2         2         0
# ss_304_11g_5x10         5' X 10'            15        16         0
# ss_304_11g _no4_5x10         NaN             0         4         0
# ss_304_14g_5x10         5' X 10'             5         4         1
# ss_304_16g_5x10         5' X 10'             5         9         0
# ss_304_16g_no4_5x10     5' X 10'             2         3         0
# ss_316_16g_4x8               NaN             0         1         0
# steel_44w_0.187_5x10    5' X 10'            34        33         1
# steel_44w_0.250_5x10    5' X 10'            39        22        17
# steel_44w_0.312_5x10    5' X 10'             4         1         3
# steel_44w_0.375_5x10    5' X 10'             8         1         7
# steel_44w_0.500_5x10    5' X 10'             6         5         1
# steel_44w_0.625_5x10    5' X 10'             2         2         0
# steel_44w_0.750_5x10    5' X 10'             2         1         1
# steel_44w_1.000_4x8          NaN             0         3         0
# steel_44w_1.000_5x10    5' X 10'             2         3         0
# steel_com_10g_5x10      5' X 10'             2         6         0
# steel_com_11g_5x10      5' X 10'            54        43        11
# steel_com_14g_5x10      5' X 10'            10        13         0
# steel_com_16g_4x8            NaN             0        12         0
# steel_com_16g_5x10      5' X 10'            15        13         2
# steel_flr_0.187_5x10    5' X 10'             8         8         0
# steel_galv_11g_4x10     4' X 10'             3         4         0
#
#                        Surface (ft^2)
# stock_ident_no
# ss 304 2b 0.187 5x10               50
# ss_304_0.187_no4_5x10               0
# ss_304_0.250_5x10                   0
# ss_304_0.250_no4_5x10               0
# ss_304_0.375_5x10                  50
# ss_304_0.500_5x10                   0
# ss_304_11g_5x10                     0
# ss_304_11g _no4_5x10                0
# ss_304_14g_5x10                    50
# ss_304_16g_5x10                     0
# ss_304_16g_no4_5x10                 0
# ss_316_16g_4x8                      0
# steel_44w_0.187_5x10               50
# steel_44w_0.250_5x10              850
# steel_44w_0.312_5x10              150
# steel_44w_0.375_5x10              350
# steel_44w_0.500_5x10               50
# steel_44w_0.625_5x10                0
# steel_44w_0.750_5x10               50
# steel_44w_1.000_4x8                 0
# steel_44w_1.000_5x10                0
# steel_com_10g_5x10                  0
# steel_com_11g_5x10                550
# steel_com_14g_5x10                  0
# steel_com_16g_4x8                   0
# steel_com_16g_5x10                100
# steel_flr_0.187_5x10                0
# steel_galv_11g_4x10                 0

# %%
now = datetime.now().strftime("%Y_%m_%d(%Hh%Mm%S)")
filename = "bestand_" + now + ".xlsx"
bestand.to_excel(filename)  # add date in file name.
